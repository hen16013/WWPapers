# %%
import pandas as pd
import altair as alt

# %%
mydat = pd.read_csv("../raw data/2022-12-12-pages-export.csv")

# %%
mydat
# Out:
#        Internal ID Document Type  Parent ID  \
# 0            24132           NaN        NaN
# 1            24131           NaN        NaN
# 2            24130           NaN        NaN
# 3            24129           NaN        NaN
# 4            24128           NaN        NaN
# ...            ...           ...        ...
# 22837            5      Journals      665.0
# 22838            4      Journals      665.0
# 22839            3      Journals      665.0
# 22840            2      Journals      665.0
# 22841            1      Journals      665.0
#
#                                          Parent Name  \
# 0                 Wilford Woodruff Bible, 1830 [R-4]
# 1                 Wilford Woodruff Bible, 1830 [R-4]
# 2                 Wilford Woodruff Bible, 1830 [R-4]
# 3                 Wilford Woodruff Bible, 1830 [R-4]
# 4                 Wilford Woodruff Bible, 1830 [R-4]
# ...                                              ...
# 22837  Journal (December 29, 1833 – January 3, 1838)
# ...
